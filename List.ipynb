# %% [markdown]
# ## 清單 List

# %%
my_list = [1,2,3, 'hello world']

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# ### List 基本操作

# %%
my_list = [5,6,7, 's']
my_list[0]
# Out:
# 5

# %%
my_list[1]
# Out:
# 6

# %%
my_list[-1]
# Out:
# 's'

# %%
my_list[1:3]
# Out:
# [6, 7]

# %%
my_list[::2]
# Out:
# [5, 7]

# %%
my_list[::-1]
# Out:
# ['s', 7, 6, 5]

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ### List 元素增減

# %%
my_list = [5,6,7,8]

# %%
my_list.pop()
# Out:
# 8

# %%
my_list.append(2)

# %%
my_list
# Out:
# [5, 6, 7, 2]

# %%
my_list.sort()

# %%
my_list
# Out:
# [2, 5, 6, 7]

# %%
my_list.reverse()

# %%
my_list
# Out:
# [7, 6, 5, 2]

# %% [markdown]
# ### List 與字串間的轉換

# %%
s = 'Hello World'
list(s)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
' '.join(list(s))
# Out:
# 'H e l l o   W o r l d'

# %% [markdown]
# ### Copy List

# %%
a = 200
b = a

# %%
a
# Out:
# 200

# %%
b
# Out:
# 200

# %%
b = 20

# %%
a
# Out:
# 200

# %%
b
# Out:
# 20

# %%
a = [1,2,3]
b = a
a[1] = 200
b
# Out:
# [1, 200, 3]

# %%
a = [1,2,3]
b = a.copy()
a[1] = 200
b
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [1, 200, 3]

# %% [markdown]
# ### 練習題
# 中位數的定義是，將資料排序後取最中間的值。
#
# 假設有一家公司，他們的員工年薪(單位：千元)分別為：
#
# ````
# [880, 890, 630, 730, 640, 690, 690, 980, 650, 760, 1190, 670, 790, 1290, 1120, 1260, 680, 1210, 1110, 1150, 790, 1220, 1220, 980, 820, 920, 700, 890, 1190, 760, 1150]
# ````
#
# 請利用Python 的List 找出這家公司員工的薪水中位數為？

# %%
salary = [880, 890, 630, 730, 640, 690, 690, 980, 650, 760, 1190, 670, 790, 1290, 1120, 1260, 680, 1210, 1110, 1150, 790, 1220, 1220, 980, 820, 920, 700, 890, 1190, 760, 1150]

# %%
salary.sort()

# %%
print(salary)
# Out:
# [630, 640, 650, 670, 680, 690, 690, 700, 730, 760, 760, 790, 790, 820, 880, 890, 890, 920, 980, 980, 1110, 1120, 1150, 1150, 1190, 1190, 1210, 1220, 1220, 1260, 1290]

# %%
len(salary)
# Out:
# 31

# %%
int(len(salary) / 2)
# Out:
# 15

# %%
salary[15]
# Out:
# 890
