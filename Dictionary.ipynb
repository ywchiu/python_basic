# %% [markdown]
# ## 字典 (Dictionary)

# %% [markdown]
# ### 字典基本操作

# %%
dic = {'David': 50000, 'Jean': 38000, 'Marry': 70000}

# %%
type(dic)
# Out:
# dict

# %%
dic.keys()
# Out:
# dict_keys(['David', 'Jean', 'Marry'])

# %%
dic.values()
# Out:
# dict_values([50000, 38000, 70000])

# %% [markdown]
# ### 取得Key 對應到的內容

# %%
dic['Jean']
# Out:
# 38000

# %%
dic['John']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-d3617b67f770> in <module>()
# ----> 1 dic['John']
#
# KeyError: 'John'

# %%
dic.get('Jean')
# Out:
# 38000

# %%
dic.get('John')

# %%
print(dic.get('John'))
# Out:
# None

# %%
# ?dic.get

# %%
print(dic.get('John', '查無此人'))
# Out:
# 查無此人

# %%
print(dic.get('Jean', '查無此人'))
# Out:
# 38000

# %% [markdown]
# ### 更新字典內容

# %%
dic
# Out:
# {'David': 50000, 'Jean': 38000, 'Marry': 70000}

# %%
dic['John'] = 55000

# %%
dic
# Out:
# {'David': 50000, 'Jean': 38000, 'John': 55000, 'Marry': 70000}

# %%
dic2 = {'David': 60000, 'Sean': 55000}
dic.update(dic2)

# %%
dic
# Out:
# {'David': 60000, 'Jean': 38000, 'John': 55000, 'Marry': 70000, 'Sean': 55000}

# %% [markdown]
# ### 練習題
#
# 我們希望建立一個對話機器人, 機器人裡面內建一個資料問答資料庫, 資料庫的問題跟答案如下所示:
#
# - 問題:我要保保險 答案: 以下是我們推薦的險總類
# - 問題:我要貸款     答案: 以下是我們推薦的貸款總類
# - 問題:我要查餘額  答案: 以下是您的銀行存款餘額
#
# 希望你能用這個問答資料庫建立成一個Python 字典, 當使用者輸入問題時, 可以根據問答資料庫回答答案, 但是如果問題不在資料庫之中，請答：我現在還不聰明，等我變聰明以後再回答你
#
# **提示: 要使用 get 的語法**

# %%
qa = {
  '我要保保險'  : '以下是我們推薦的險總類',
  '我要貸款' : '以下是我們推薦的貸款總類',
  '我要查餘額': '以下是您的銀行存款餘額'
}

question = input('請輸入您的問題:')
qa.get(question, '我現在還不聰明，等我變聰明以後再回答你')
# Out:
# 請輸入您的問題:吃過早餐了沒
# '我現在還不聰明，等我變聰明以後再回答你'
