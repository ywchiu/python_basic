# %% [markdown]
# ## 套件 (package)

# %% [markdown]
# ### 建立套件

# %%
from child import demo
demo.func('David')
# Out:
# 'Hello, David'

# %% [markdown]
# ### 套件命名空間

# %%
import child
child.demo.func('David')
# Out:
# 'Hello, David'

# %%
from child import demo
demo.func('David')
# Out:
# 'Hello, David'

# %%
from child.demo import *
func('David')
# Out:
# 'Hello, David'
