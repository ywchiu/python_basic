# %% [markdown]
# ## 迭代器 (Iterator)

# %% [markdown]
# ### FOR...IN...

# %%
li = [1,2,3]
for e in li:
  print(e)
# Out:
# 1
# 2
# 3

# %%
for e in li:
  print(e)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Iter

# %%
li = [1,2,3]
it = iter(li)
type(it)
# Out:
# list_iterator

# %% [markdown]
# ### Next

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
next(it)
# Out:
# 3

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-24-bc1ab118995a> in <module>()
# ----> 1 next(it)
#
# StopIteration:

# %% [markdown]
# ### For...Loop v.s. Iterator

# %%
li = [1,2,3]
for e in li:
  print(e)
# Out:
# 1
# 2
# 3

# %%
li = [1,2,3]
it = iter(li)
while True:
  try:
    print(next(it))
  except StopIteration:
    break
# Out:
# 1
# 2
# 3
